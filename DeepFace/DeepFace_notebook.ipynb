# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('img//JOIE.jpg')

# Convert the image to RGB
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Plot the image
plt.imshow(rgb_img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
from deepface import DeepFace

predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.82it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 4.687073764259427e-06,
#    'disgust': 6.957204866978974e-11,
#    'fear': 2.8865541012675835e-06,
#    'happy': 97.70095930701251,
#    'sad': 3.50599286072679e-06,
#    'surprise': 0.0009753852863676458,
#    'neutral': 2.298052559676919},
#   'dominant_emotion': 'happy',
#   'region': {'x': 153, 'y': 69, 'w': 148, 'h': 148},
#   'age': 27,
#   'gender': {'Woman': 8.841319072416809e-05, 'Man': 99.99991655349731},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.0018926847806496787,
#    'indian': 0.09287836118062504,
#    'black': 0.00023646142880964926,
#    'white': 78.85150187322509,
#    'middle eastern': 18.955106672948997,
#    'latino hispanic': 2.098384065829758},
#   'dominant_race': 'white'}]

# %%
print(type(predictions))
# Out:
# <class 'list'>

# %%
print(predictions)
# Out:
# [{'emotion': {'angry': 4.687073764259427e-06, 'disgust': 6.957204866978974e-11, 'fear': 2.8865541012675835e-06, 'happy': 97.70095930701251, 'sad': 3.50599286072679e-06, 'surprise': 0.0009753852863676458, 'neutral': 2.298052559676919}, 'dominant_emotion': 'happy', 'region': {'x': 153, 'y': 69, 'w': 148, 'h': 148}, 'age': 27, 'gender': {'Woman': 8.841319072416809e-05, 'Man': 99.99991655349731}, 'dominant_gender': 'Man', 'race': {'asian': 0.0018926847806496787, 'indian': 0.09287836118062504, 'black': 0.00023646142880964926, 'white': 78.85150187322509, 'middle eastern': 18.955106672948997, 'latino hispanic': 2.098384065829758}, 'dominant_race': 'white'}]

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray, 1.1,4)
for (w, x, y, z) in faces : 
    cv2.rectangle(img, (w,x), (w + y, x + z), (0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions[0]['dominant_emotion'], (0, 50), font, 2, (0, 0, 255), 2, cv2.LINE_4)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
