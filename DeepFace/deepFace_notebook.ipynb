# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('surprise.jpg')
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
from deepface import DeepFace

predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.88it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 4.671862254849807,
#    'disgust': 9.725233927524833e-13,
#    'fear': 95.31744094594961,
#    'happy': 0.0017591642202101742,
#    'sad': 2.494627764281563e-06,
#    'surprise': 0.008938101914980004,
#    'neutral': 1.4863468228971821e-13},
#   'dominant_emotion': 'fear',
#   'region': {'x': 153, 'y': 47, 'w': 224, 'h': 224},
#   'age': 27,
#   'gender': {'Woman': 0.00013273070180730429, 'Man': 99.9998688697815},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.10072930017486215,
#    'indian': 2.560649998486042,
#    'black': 0.10435862932354212,
#    'white': 72.51766324043274,
#    'middle eastern': 17.277565598487854,
#    'latino hispanic': 7.439030706882477},
#   'dominant_race': 'white'}]

# %%
print(type(predictions))
# Out:
# <class 'list'>

# %%
print(predictions)
# Out:
# [{'emotion': {'angry': 4.671862254849807, 'disgust': 9.725233927524833e-13, 'fear': 95.31744094594961, 'happy': 0.0017591642202101742, 'sad': 2.494627764281563e-06, 'surprise': 0.008938101914980004, 'neutral': 1.4863468228971821e-13}, 'dominant_emotion': 'fear', 'region': {'x': 153, 'y': 47, 'w': 224, 'h': 224}, 'age': 27, 'gender': {'Woman': 0.00013273070180730429, 'Man': 99.9998688697815}, 'dominant_gender': 'Man', 'race': {'asian': 0.10072930017486215, 'indian': 2.560649998486042, 'black': 0.10435862932354212, 'white': 72.51766324043274, 'middle eastern': 17.277565598487854, 'latino hispanic': 7.439030706882477}, 'dominant_race': 'white'}]

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray, 1.1,4)
for (w, x, y, z) in faces : 
    cv2.rectangle(img, (w,x), (w + y, x + z), (0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions[0]['dominant_emotion'], (0, 50), font, 2, (0, 0, 255), 2, cv2.LINE_4)
# Out:
# array([[[254, 253, 255],
#         [255, 254, 255],
#         [255, 254, 255],
#         ...,
#         [253, 255, 255],
#         [252, 254, 255],
#         [253, 255, 255]],
#
#        [[253, 252, 254],
#         [254, 253, 255],
#         [255, 254, 255],
#         ...,
#         [253, 255, 255],
#         [253, 255, 255],
#         [253, 255, 255]],
#
#        [[136, 138, 139],
#         [137, 139, 140],
#         [138, 140, 141],
#         ...,
#         [165, 167, 168],
#         [163, 165, 166],
#         [163, 165, 166]],
#
#        ...,
#
#        [[128, 131, 135],
#         [127, 130, 134],
#         [131, 134, 138],
#         ...,
#         [165, 169, 170],
#         [163, 167, 168],
#         [163, 167, 168]],
#
#        [[127, 130, 134],
#         [126, 129, 133],
#         [129, 132, 136],
#         ...,
#         [166, 170, 171],
#         [163, 167, 168],
#         [163, 167, 168]],
#
#        [[127, 130, 134],
#         [125, 128, 132],
#         [126, 129, 133],
#         ...,
#         [168, 172, 173],
#         [164, 168, 169],
#         [163, 167, 168]]], dtype=uint8)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
